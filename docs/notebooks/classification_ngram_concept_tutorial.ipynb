# %% [markdown]
# ![interpreto_banner](../assets/img/interpreto_banner.png)
#
# # Classification Concept-based N-gram Explanation Tutorial
#
# This tutorial shows how to extract and interpret concepts for a classification task using n-gram words, in two settings: **globally** and **per class**.
#
# - **Globally**: we decompose the activations of the **entire** validation set to obtain **k concepts in total**.
# - **Per class**: we decompose the activations of data from **each class separately**, obtaining **k concepts per class**.
#
# Several decomposition methods are available (e.g. Semi-NMF, PCA, etc.).
# For more details, please refer to the [**Interpreto documentation**](https://for-sight-ai.github.io/interpreto/).
#
# ### How it works
#
# **Extracting concepts**: we use `CLS_TOKEN` granularity, meaning only the CLS token activation of each input is kept. The decomposition (fit) is then performed on these CLS token activations, producing a concept space of k dimensions.
#
# **Interpreting concepts with n-grams**: to find which words or groups of words best represent each concept, we extract all unique n-grams (groups of up to n consecutive words) from the dataset and pass each n-gram individually to the model. We take its CLS token activation and project it into the concept space obtained during the fit. The n-grams whose projections activate a concept the most are selected to represent the concept.
#
# Using n-grams (2, 3, or more words) rather than single words seems to give more meaningful results: a single word passed alone to the model often lacks context, producing a less informative CLS activation.
#
#
# ## 1. Global n-gram concept interpretation
#
# Extract **k concepts from all activations**, then interpret them with n-grams.
#
# 1. [➗ **Split** your model in two parts](#split-global)
# 2. [🚦 Compute **CLS token activations** on the whole test set](#activations-global)
# 3. [🏋️‍♂️ **Decompose** the CLS activation space to obtain k concepts](#fit-global)
# 4. [🏷️ **Interpret** each concept by projecting n-gram activations into the concept space](#interpret-global)
# 5. [📊 Compute the **importance** of each concept for each class](#important-global)
# 6. [🔍 **Visualize** concept importance and n-gram labels](#visualize-global)
#
# ## 2. Class-wise n-gram concept interpretation
#
# Extract **k concepts per class** by decomposing only the CLS activations of data from that class, then interpret them with n-grams.
#
# 1. [🚦 Compute **CLS token activations** for each class separately](#activations-perclass)
# 2. [🏋️‍♂️ **Decompose** the CLS activation space of each class to obtain k concepts per class](#fit-perclass)
# 3. [🏷️ **Interpret** each concept by projecting n-gram activations into the concept space](#interpret-perclass)
# 4. [📊 Compute the **importance** of each concept for its class](#important-perclass)
# 5. [🔍 **Visualize** concept importance and n-gram labels per class](#visualize-perclass)

# %%
import torch

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# utils
from IPython.display import display, HTML
import json

def display_topngram_dropdown(topngram_words):
    data_json = json.dumps({
        str(k): [{"ngram": ng, "score": f"{s:.4f}"} for ng, s in v.items()]
        for k, v in topngram_words.items()
    })

    options_html = "".join(f'<option value="{k}">{k}</option>' for k in sorted(topngram_words.keys()))

    html = f"""
    <select id="concept-select" onchange="updateTable()">
    {options_html}
    </select>
    <table id="concept-table" border="1" style="margin-top:8px"></table>
    <script>
    var data = {data_json};
    function updateTable() {{
        var key = document.getElementById('concept-select').value;
        var rows = data[key];
        var html = '<tr><th>ngram</th><th>score</th></tr>';
        rows.forEach(function(r) {{ html += '<tr><td>'+r.ngram+'</td><td>'+r.score+'</td></tr>'; }});
        document.getElementById('concept-table').innerHTML = html;
    }}
    updateTable();
    </script>
    """
    display(HTML(html))

# %% [markdown]
# # 1. Global n-gram concept interpretation

# %% [markdown]
# ## 1. ➗ **Split** your model in two parts <a class="anchor" id="split"></a>
#
# We choose a `bert` fine-tuned on the `go-emotions` dataset and split it just before the classification head.
#
# To split the model, we use the [`interpreto.ModelWithSplitPoints`](https://for-sight-ai.github.io/interpreto/api/concepts/model_with_split_points/) which wraps around the `transformers` model and allows the computation of activations at the specified `split_points`.

# %%
from transformers import AutoModelForSequenceClassification

from interpreto import ModelWithSplitPoints

model_with_split_points = ModelWithSplitPoints(
    model_or_repo_id="SchuylerH/bert-multilingual-go-emtions",
    automodel=AutoModelForSequenceClassification,
    split_points=[5],  # split at the sixth layer
    device_map="cuda",
    batch_size=32,
)

# %% [markdown]
# ## 2. 🚦 Compute a datasets of **activations** <a class="anchor" id="activations"></a>
#
# We load the first 10000 documents of the `go_emotions` validation set.
#
# Then we extract the activations of the [CLS] token of each document.
#
# > ➡️ **Common practice**
# >
# > In the literature, to train concepts for classification it is common to use the [CLS] just before the classification head.
# >
# > In fact, at this layer, it makes no sense to use other elements.
#
# > ⚠️ **Warning**
# >
# > In this notebook, many things are specific to the use of the [CLS] token.
#
# [`interpreto.ModelWithSplitPoints.get_activations()`](https://for-sight-ai.github.io/interpreto/api/concepts/model_with_split_points/#interpreto.ModelWithSplitPoints.get_activations)

# %%
from datasets import load_dataset

# load the AG-News dataset
dataset = load_dataset("google-research-datasets/go_emotions", "simplified")
inputs = list(dataset["validation"]["text"])
classes_names = dataset["validation"].features["labels"].feature.names

# Compute the [CLS] token activations
granularity = ModelWithSplitPoints.activation_granularities.CLS_TOKEN # required for ngram interpretation.
activations = model_with_split_points.get_activations(
    inputs=inputs,
    activation_granularity=granularity,
    include_predicted_classes=True,
)

# %% [markdown]
# ## 3. 🏋️‍♂️ **Fit** a concept model on activations <a class="anchor" id="fit"></a>
#
# With activations, we can train a concept model to find patterns (concepts).
#
# The `concept_model` is an attribute of our concept explainer, similarly to the `model_with_split_points`. With these these two elements, we can go from inputs to concepts and from concepts to outputs.
#
# In this tutorial, we use [`interpreto.concepts.SemiNMFConcepts`](https://for-sight-ai.github.io/interpreto/api/concepts/methods/optim/#interpreto.concepts.SemiNMFConcepts). There are at least 15 others concept model available in interpreto. do not hesitate to explore them.

# %%
from interpreto.concepts import SemiNMFConcepts

# instantiate the concept explainer
concept_explainer = SemiNMFConcepts(model_with_split_points, nb_concepts=50, device="cuda") # nb: nb_concept must be bigger than the number of classes, since there should be at least 1 concept = 1 class

# fit the concept explainer on activations
concept_explainer.fit(activations)

# %% [markdown]
# ## 4. 🏷️ **Interpret** the concept dimensions <a class="anchor" id="interpret"></a>
#
# We need to make sense of these concepts. In this case, we will use the [`interpreto.concepts.interpretations.TopKInputs`](https://for-sight-ai.github.io/interpreto/api/concepts/concepts_interpretations/#interpreto.concepts.interpretations.TopKInputs) to find the k (here, 5) ngram words (here 6 grams) which activates the most our concepts.
#
# The `unique_words_kwargs` parameter controls how n-grams are extracted from the dataset before being passed to the model:
#
# - **`count_min_threshold`**: minimum number of occurrences for an n-gram to be kept. Increase this value if irrelevant or noisy n-grams appear in the results; decrease it if meaningful n-grams are filtered out.
# - **`lemmatize`**: if `True`, words are reduced to their base form before forming n-grams (e.g. "running" → "run", "cats" → "cat"). This avoids duplicates like "run" and "running" being treated as separate n-grams.
# - **`words_to_ignore`**: list of words to exclude before forming n-grams (e.g. punctuation, stopwords, or domain-specific noise).

# %%
from interpreto.concepts.interpretations import TopKInputs

# instantiate the interpretation method with the concept explainer
topngram_inputs_method = TopKInputs(
    concept_explainer=concept_explainer,
    k=5,
    activation_granularity=granularity,
    use_unique_words=6,  # 6-grams words. Put 1 to get unique words only. With the [CLS] token granularity, we are forced to use unique words
    unique_words_kwargs={
        "count_min_threshold": round(
            len(inputs) * 0.002
        ),  # appear in at least 0.2% of the samples | increase if random ngrams appear and decrease if some ngram appear too often
        "lemmatize": True,
        "words_to_ignore": [],  # include noise words and punctuation
    },
)

# %%
topngram_words = topngram_inputs_method.interpret(
    inputs=inputs,
    concepts_indices="all",
)
display_topngram_dropdown(topngram_words)
# Out:
#     <select id="concept-select" onchange="updateTable()">
#     <option value="0">0</option><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="16">16</option><option value="17">17</option><option value="18">18</option><option value="19">19</option><option value="20">20</option><option value="21">21</option><option value="22">22</option><option value="23">23</option><option value="24">24</option><option value="25">25</option><option value="26">26</option><option value="27">27</option><option value="28">28</option><option value="29">29</option><option value="30">30</option><option value="31">31</option><option value="32">32</option><option value="33">33</option><option value="34">34</option><option value="35">35</option><option value="36">36</option><option value="37">37</option><option value="38">38</option><option value="39">39</option><option value="40">40</option><option value="41">41</option><option value="42">42</option><option value="43">43</option><option value="44">44</option><option value="45">45</option><option value="46">46</option><option value="47">47</option><option value="48">48</option><option value="49">49</option>
#     </select>
#     <table id="concept-table" border="1" style="margin-top:8px"></table>
#     <script>
#     var data = {"0": [{"ngram": "haha", "score": "0.3418"}, {"ngram": "lol", "score": "0.3272"}, {"ngram": "it 's not", "score": "0.2761"}, {"ngram": "right", "score": "0.2723"}, {"ngram": "it \u2019 s not", "score": "0.2699"}], "1": [{"ngram": "sorry for", "score": "0.3407"}, {"ngram": "sorry", "score": "0.3321"}, {"ngram": "so sorry", "score": "0.2441"}, {"ngram": "the kid", "score": "0.2039"}, {"ngram": "too .", "score": "0.1819"}], "2": [{"ngram": "true", "score": "0.2687"}, {"ngram": "] and [ name ]", "score": "0.2606"}, {"ngram": "] , [ name ]", "score": "0.2555"}, {"ngram": "[ name ]", "score": "0.2524"}, {"ngram": "why", "score": "0.2479"}], "3": [{"ngram": "card", "score": "0.3874"}, {"ngram": "guy", "score": "0.3869"}, {"ngram": "black", "score": "0.3797"}, {"ngram": "person", "score": "0.3786"}, {"ngram": "dumb", "score": "0.3758"}], "4": [{"ngram": "happy", "score": "0.2730"}, {"ngram": "so happy", "score": "0.2652"}, {"ngram": "enjoy", "score": "0.2481"}, {"ngram": "appreciate", "score": "0.2198"}, {"ngram": "living", "score": "0.2103"}], "5": [{"ngram": "surprised", "score": "0.2848"}, {"ngram": "i don \u2019 t", "score": "0.2482"}, {"ngram": "i can \u2019 t", "score": "0.2385"}, {"ngram": "not the", "score": "0.2377"}, {"ngram": "\u2019 t think", "score": "0.2348"}], "6": [{"ngram": "talking about", "score": "0.2371"}, {"ngram": "live in", "score": "0.2138"}, {"ngram": "seen", "score": "0.2117"}, {"ngram": "i agree", "score": "0.2080"}, {"ngram": "talking", "score": "0.1846"}], "7": [{"ngram": "lol", "score": "0.4020"}, {"ngram": "lol ,", "score": "0.3466"}, {"ngram": "oh", "score": "0.3453"}, {"ngram": "lol .", "score": "0.3354"}, {"ngram": "haha", "score": "0.3300"}], "8": [{"ngram": "care about", "score": "0.3057"}, {"ngram": "job", "score": "0.2703"}, {"ngram": "yourself", "score": "0.2677"}, {"ngram": "'", "score": "0.2529"}, {"ngram": ">", "score": "0.2494"}], "9": [{"ngram": "i love the", "score": "0.2292"}, {"ngram": "i love it", "score": "0.2252"}, {"ngram": "love it .", "score": "0.2227"}, {"ngram": "i love this", "score": "0.2193"}, {"ngram": "talking about", "score": "0.2135"}], "10": [{"ngram": "why", "score": "0.2278"}, {"ngram": "that \u2019 s what", "score": "0.2273"}, {"ngram": "\u2019 s what", "score": "0.2214"}, {"ngram": ": (", "score": "0.2124"}, {"ngram": "s what", "score": "0.2042"}], "11": [{"ngram": "alone", "score": "0.2247"}, {"ngram": "absolutely", "score": "0.2020"}, {"ngram": "half", "score": "0.1993"}, {"ngram": "i feel", "score": "0.1871"}, {"ngram": "glad", "score": "0.1850"}], "12": [{"ngram": "hit", "score": "0.2942"}, {"ngram": "she", "score": "0.2909"}, {"ngram": "he", "score": "0.2852"}, {"ngram": "together", "score": "0.2764"}, {"ngram": "i really", "score": "0.2718"}], "13": [{"ngram": "i hope you", "score": "0.3605"}, {"ngram": "hope you", "score": "0.3280"}, {"ngram": "i hope", "score": "0.3217"}, {"ngram": "hope", "score": "0.3169"}, {"ngram": ". i hope", "score": "0.3022"}], "14": [{"ngram": "care about", "score": "0.2824"}, {"ngram": "i wish", "score": "0.2782"}, {"ngram": "hope you", "score": "0.2737"}, {"ngram": "hope", "score": "0.2732"}, {"ngram": "thought", "score": "0.2680"}], "15": [{"ngram": "like this", "score": "0.2791"}, {"ngram": "like it", "score": "0.2655"}, {"ngram": "favourite", "score": "0.2475"}, {"ngram": "i like", "score": "0.2436"}, {"ngram": "my favorite", "score": "0.2336"}], "16": [{"ngram": "my favorite", "score": "0.3419"}, {"ngram": "good luck", "score": "0.2684"}, {"ngram": "favorite", "score": "0.2388"}, {"ngram": "glad to", "score": "0.1965"}, {"ngram": "unfortunately", "score": "0.1954"}], "17": [{"ngram": "lmao", "score": "0.3152"}, {"ngram": "i can \u2019 t", "score": "0.2925"}, {"ngram": "i can \u2019", "score": "0.2510"}, {"ngram": "amazing", "score": "0.2458"}, {"ngram": "biggest", "score": "0.2429"}], "18": [{"ngram": "i want", "score": "0.3130"}, {"ngram": "so happy", "score": "0.3008"}, {"ngram": "cute", "score": "0.2649"}, {"ngr ...

# %%
import torch

# estimate the importance of concepts for each class using the gradient
gradients = concept_explainer.concept_output_gradient(
    inputs=inputs,
    targets=None,  # None means all classes
    activation_granularity=granularity,
    concepts_x_gradients=True,  # the concept to output gradients are multiplied by the concepts values, this is common practice in the literature
    batch_size=32,
)

# stack gradients on samples and average them over samples
mean_gradients = torch.stack(gradients).abs().squeeze().mean(0)  # (num_classes, num_concepts)

# for each class, sort the importance scores
order = torch.argsort(mean_gradients, descending=True)

# visualize the top 5 concepts for each class
for target in range(order.shape[0]):
    print(f"\nClass: {classes_names[target]}:")
    for i in range(5):
        concept_id = order[target, i].item()
        importance = mean_gradients[target, concept_id].item()
        words = list(topngram_words.get(concept_id, None).keys())
        print(f"\tconcept id: {concept_id},\timportance: {round(importance, 3)},\ttopk words: {words}")
# Out:
# Class: admiration:
# 	concept id: 30,	importance: 0.033,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 12,	importance: 0.032,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 43,	importance: 0.032,	topk words: ['awesome', 'awesome .', 'is awesome', 'appreciate', 'the best']
# 	concept id: 6,	importance: 0.029,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
# 	concept id: 10,	importance: 0.028,	topk words: ['why', 'that ’ s what', '’ s what', ': (', 's what']
#
# Class: amusement:
# 	concept id: 11,	importance: 0.031,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 40,	importance: 0.031,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 30,	importance: 0.03,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 45,	importance: 0.027,	topk words: ['sorry for', 'so sorry', 'sorry', 'disgusting', 'stupid']
# 	concept id: 29,	importance: 0.025,	topk words: ['a [ name', '[ name ] is', 'a [ name ]', 'the [ name ]', 'the [ name']
#
# Class: anger:
# 	concept id: 30,	importance: 0.028,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 6,	importance: 0.026,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
# 	concept id: 11,	importance: 0.026,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 37,	importance: 0.026,	topk words: ['kill', 'wish', 'think', 'want', 'is what']
# 	concept id: 23,	importance: 0.025,	topk words: ['she', 'they were', '! ! ! ! !', '! ! ! ! ! !', 'that ’ s what']
#
# Class: annoyance:
# 	concept id: 30,	importance: 0.034,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 37,	importance: 0.032,	topk words: ['kill', 'wish', 'think', 'want', 'is what']
# 	concept id: 13,	importance: 0.029,	topk words: ['i hope you', 'hope you', 'i hope', 'hope', '. i hope']
# 	concept id: 6,	importance: 0.028,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
# 	concept id: 40,	importance: 0.025,	topk words: ['money', 'news', 'future', 'advice', 'music']
#
# Class: approval:
# 	concept id: 12,	importance: 0.037,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 20,	importance: 0.029,	topk words: ['i love this', 'i love it', 'i love the', 'love it', 'love it .']
# 	concept id: 29,	importance: 0.029,	topk words: ['a [ name', '[ name ] is', 'a [ name ]', 'the [ name ]', 'the [ name']
# 	concept id: 38,	importance: 0.029,	topk words: ['saying', 'for me', '>', 'me .', 'doing']
# 	concept id: 14,	importance: 0.029,	topk words: ['care about', 'i wish', 'hope you', 'hope', 'thought']
#
# Class: caring:
# 	concept id: 48,	importance: 0.033,	topk words: ['when it', 'when you', 'when they', 'when i', 'i thought it']
# 	concept id: 12,	importance: 0.031,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 1,	importance: 0.028,	topk words: ['sorry for', 'sorry', 'so sorry', 'the kid', 'too .']
# 	concept id: 25,	importance: 0.027,	topk words: ['can ’ t', 'welcome', 'don ’ t', "could n't", 'laugh']
# 	concept id: 16,	importance: 0.027,	topk words: ['my favorite', 'good luck', 'favorite', 'glad to', 'unfortunately']
#
# Class: confusion:
# 	concept id: 23,	importance: 0.034,	topk words: ['she', 'they were', '! ! ! ! !', '! ! ! ! ! !', 'that ’ s what']
# 	concept id: 48,	importance: 0.032,	topk words: ['when it', 'when you', 'when they', 'when i', 'i thought it']
# 	concept id: 24,	importance: 0.031,	topk words: ['the same', ', it ’', 'we ’ re', 'the last', '. it ’']
# 	concept id: 22,	importance: 0.03,	topk words: ['afraid', 'enjoy', '(', 'open', 'day .']
# 	concept id: 12,	importance: 0.029,	topk words: ['hit', 'she', 'he', 'together', 'i really']
#
# Class: curiosity:
# 	concept id: 48,	importance: 0.035,	topk words: ['when it', 'when you', 'when they', 'when i', 'i thought it']
# 	concept id: 23,	importance: 0.034,	topk words: ['she', 'they were', '! ! ! ! !', '! ! ! ! ! !', 'that ’ s what']
# 	concept id: 18,	importance: 0.031,	topk words: ['i want', 'so happy', 'cute', 'so sorry', 'this is a']
# 	concept id: 11,	importance: 0.03,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 40,	importance: 0.028,	topk words: ['money', 'news', 'future', 'advice', 'music']
#
# Class: desire:
# 	concept id: 11,	importance: 0.037,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 48,	importance: 0.033,	topk words: ['when it', 'when you', 'when they', 'when i', 'i thought it']
# 	concept id: 40,	importance: 0.032,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 30,	importance: 0.03,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 12,	importance: 0.029,	topk words: ['hit', 'she', 'he', 'together', 'i really']
#
# Class: disappointment:
# 	concept id: 30,	importance: 0.046,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 11,	importance: 0.029,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 1,	importance: 0.029,	topk words: ['sorry for', 'sorry', 'so sorry', 'the kid', 'too .']
# 	concept id: 6,	importance: 0.024,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
# 	concept id: 40,	importance: 0.024,	topk words: ['money', 'news', 'future', 'advice', 'music']
#
# Class: disapproval:
# 	concept id: 30,	importance: 0.028,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 2,	importance: 0.027,	topk words: ['true', '] and [ name ]', '] , [ name ]', '[ name ]', 'why']
# 	concept id: 37,	importance: 0.027,	topk words: ['kill', 'wish', 'think', 'want', 'is what']
# 	concept id: 6,	importance: 0.027,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
# 	concept id: 5,	importance: 0.024,	topk words: ['surprised', 'i don ’ t', 'i can ’ t', 'not the', '’ t think']
#
# Class: disgust:
# 	concept id: 30,	importance: 0.04,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 6,	importance: 0.033,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
# 	concept id: 49,	importance: 0.03,	topk words: ['disgusting', 'joke', 'a joke', 'didn ’ t', 'ha']
# 	concept id: 45,	importance: 0.028,	topk words: ['sorry for', 'so sorry', 'sorry', 'disgusting', 'stupid']
# 	concept id: 41,	importance: 0.026,	topk words: ['guess', 'i hate', 'try to', 'i would', 'you will']
#
# Class: embarrassment:
# 	concept id: 30,	importance: 0.047,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 11,	importance: 0.032,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 41,	importance: 0.029,	topk words: ['guess', 'i hate', 'try to', 'i would', 'you will']
# 	concept id: 23,	importance: 0.029,	topk words: ['she', 'they were', '! ! ! ! !', '! ! ! ! ! !', 'that ’ s what']
# 	concept id: 7,	importance: 0.028,	topk words: ['lol', 'lol ,', 'oh', 'lol .', 'haha']
#
# Class: excitement:
# 	concept id: 40,	importance: 0.035,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 45,	importance: 0.031,	topk words: ['sorry for', 'so sorry', 'sorry', 'disgusting', 'stupid']
# 	concept id: 29,	importance: 0.031,	topk words: ['a [ name', '[ name ] is', 'a [ name ]', 'the [ name ]', 'the [ name']
# 	concept id: 44,	importance: 0.027,	topk words: ['long', 'this .', 'hair', 'each', 'when i']
# 	concept id: 12,	importance: 0.027,	topk words: ['hit', 'she', 'he', 'together', 'i really']
#
# Class: fear:
# 	concept id: 30,	importance: 0.038,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 12,	importance: 0.035,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 11,	importance: 0.029,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 48,	importance: 0.027,	topk words: ['when it', 'when you', 'when they', 'when i', 'i thought it']
# 	concept id: 23,	importance: 0.027,	topk words: ['she', 'they were', '! ! ! ! !', '! ! ! ! ! !', 'that ’ s what']
#
# Class: gratitude:
# 	concept id: 27,	importance: 0.034,	topk words: ['i agree', 'confused', 'why', 'favourite', 'lost']
# 	concept id: 3,	importance: 0.032,	topk words: ['card', 'guy', 'black', 'person', 'dumb']
# 	concept id: 16,	importance: 0.03,	topk words: ['my favorite', 'good luck', 'favorite', 'glad to', 'unfortunately']
# 	concept id: 18,	importance: 0.03,	topk words: ['i want', 'so happy', 'cute', 'so sorry', 'this is a']
# 	concept id: 12,	importance: 0.029,	topk words: ['hit', 'she', 'he', 'together', 'i really']
#
# Class: grief:
# 	concept id: 30,	importance: 0.037,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 44,	importance: 0.031,	topk words: ['long', 'this .', 'hair', 'each', 'when i']
# 	concept id: 40,	importance: 0.03,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 11,	importance: 0.03,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 12,	importance: 0.03,	topk words: ['hit', 'she', 'he', 'together', 'i really']
#
# Class: joy:
# 	concept id: 40,	importance: 0.036,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 45,	importance: 0.03,	topk words: ['sorry for', 'so sorry', 'sorry', 'disgusting', 'stupid']
# 	concept id: 37,	importance: 0.027,	topk words: ['kill', 'wish', 'think', 'want', 'is what']
# 	concept id: 44,	importance: 0.027,	topk words: ['long', 'this .', 'hair', 'each', 'when i']
# 	concept id: 18,	importance: 0.026,	topk words: ['i want', 'so happy', 'cute', 'so sorry', 'this is a']
#
# Class: love:
# 	concept id: 40,	importance: 0.035,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 45,	importance: 0.035,	topk words: ['sorry for', 'so sorry', 'sorry', 'disgusting', 'stupid']
# 	concept id: 20,	importance: 0.032,	topk words: ['i love this', 'i love it', 'i love the', 'love it', 'love it .']
# 	concept id: 11,	importance: 0.029,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 6,	importance: 0.028,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
#
# Class: nervousness:
# 	concept id: 30,	importance: 0.044,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 12,	importance: 0.032,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 11,	importance: 0.031,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 48,	importance: 0.029,	topk words: ['when it', 'when you', 'when they', 'when i', 'i thought it']
# 	concept id: 41,	importance: 0.027,	topk words: ['guess', 'i hate', 'try to', 'i would', 'you will']
#
# Class: optimism:
# 	concept id: 14,	importance: 0.034,	topk words: ['care about', 'i wish', 'hope you', 'hope', 'thought']
# 	concept id: 12,	importance: 0.03,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 16,	importance: 0.03,	topk words: ['my favorite', 'good luck', 'favorite', 'glad to', 'unfortunately']
# 	concept id: 30,	importance: 0.028,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 11,	importance: 0.027,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
#
# Class: pride:
# 	concept id: 12,	importance: 0.039,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 30,	importance: 0.035,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 44,	importance: 0.031,	topk words: ['long', 'this .', 'hair', 'each', 'when i']
# 	concept id: 40,	importance: 0.027,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 23,	importance: 0.026,	topk words: ['she', 'they were', '! ! ! ! !', '! ! ! ! ! !', 'that ’ s what']
#
# Class: realization:
# 	concept id: 30,	importance: 0.031,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 11,	importance: 0.029,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 12,	importance: 0.029,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 38,	importance: 0.029,	topk words: ['saying', 'for me', '>', 'me .', 'doing']
# 	concept id: 1,	importance: 0.027,	topk words: ['sorry for', 'sorry', 'so sorry', 'the kid', 'too .']
#
# Class: relief:
# 	concept id: 30,	importance: 0.036,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 12,	importance: 0.035,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 44,	importance: 0.029,	topk words: ['long', 'this .', 'hair', 'each', 'when i']
# 	concept id: 1,	importance: 0.029,	topk words: ['sorry for', 'sorry', 'so sorry', 'the kid', 'too .']
# 	concept id: 11,	importance: 0.025,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
#
# Class: remorse:
# 	concept id: 30,	importance: 0.035,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 40,	importance: 0.031,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 48,	importance: 0.03,	topk words: ['when it', 'when you', 'when they', 'when i', 'i thought it']
# 	concept id: 6,	importance: 0.03,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
# 	concept id: 44,	importance: 0.03,	topk words: ['long', 'this .', 'hair', 'each', 'when i']
#
# Class: sadness:
# 	concept id: 30,	importance: 0.038,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 41,	importance: 0.029,	topk words: ['guess', 'i hate', 'try to', 'i would', 'you will']
# 	concept id: 11,	importance: 0.029,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 40,	importance: 0.028,	topk words: ['money', 'news', 'future', 'advice', 'music']
# 	concept id: 44,	importance: 0.028,	topk words: ['long', 'this .', 'hair', 'each', 'when i']
#
# Class: surprise:
# 	concept id: 30,	importance: 0.034,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 7,	importance: 0.032,	topk words: ['lol', 'lol ,', 'oh', 'lol .', 'haha']
# 	concept id: 23,	importance: 0.032,	topk words: ['she', 'they were', '! ! ! ! !', '! ! ! ! ! !', 'that ’ s what']
# 	concept id: 11,	importance: 0.03,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 40,	importance: 0.028,	topk words: ['money', 'news', 'future', 'advice', 'music']
#
# Class: neutral:
# 	concept id: 30,	importance: 0.036,	topk words: ['disgusting', 'surprised', 'so sorry', 'appreciate', 'sorry for']
# 	concept id: 12,	importance: 0.032,	topk words: ['hit', 'she', 'he', 'together', 'i really']
# 	concept id: 6,	importance: 0.029,	topk words: ['talking about', 'live in', 'seen', 'i agree', 'talking']
# 	concept id: 11,	importance: 0.028,	topk words: ['alone', 'absolutely', 'half', 'i feel', 'glad']
# 	concept id: 44,	importance: 0.027,	topk words: ['long', 'this .', 'hair', 'each', 'when i']

# %%
from interpreto import plot_concepts

labels = {k: list(v.keys()) for k, v in topngram_words.items()}

plot_concepts(
    classes_names=classes_names,
    concepts_importances=mean_gradients,
    concepts_labels=labels,
)
# Out:
# <head><style>
# /*
# *   CSS styling for explanation visualizations
# */
#
# /* Light mode */
# :root {
#   --default-background-color: white;
#   --default-text-color: black;
#   --visualization-font-family: "IBM Plex Sans", "Fira Sans", "Segoe UI", sans-serif;
#   --visualization-font-size: 14px;
#   --visualization-token-font-size: 1.1em;
#   --visualization-heading-font-size: 1.15em;
#   --visualization-tooltip-font-size: 0.85em;
#   --visualization-line-height: 1.5;
# }
#
# /* Dark mode */
# @media (prefers-color-scheme: dark) {
#   :root {
#     --default-background-color: hsl(225, 10%, 15%);
#     --default-text-color: hsl(230, 10%, 85%);
#   }
# }
#
# :root {
#   /* Set the text color and background color depending on the current
#   * vscode theme if available, or on the current light/dark mode if in
#   * a browser
#   */
#   --background-color: var(--vscode-editor-background,
#       var(--default-background-color));
#   --text-color: var(--vscode-editor-foreground, var(--default-text-color));
#
#   --positive-color: #ff0000;
#   --negative-color: #0000ff;
#
#   /* Reversed colors  */
#   --reversed-background-color: var(--text-color);
#   --reversed-text-color: var(--background-color);
# }
#
# .body-visualization {
#   background-color: var(--background-color);
#   color: var(--text-color);
#   font-family: var(--visualization-font-family);
#   font-size: var(--visualization-font-size);
#   line-height: var(--visualization-line-height);
#   margin: 0;
#   padding: 0;
# }
#
# .body-visualization button,
# .body-visualization input,
# .body-visualization select,
# .body-visualization textarea {
#   font-family: var(--visualization-font-family);
#   font-size: inherit;
# }
#
# .body-visualization h3 {
#   font-size: var(--visualization-heading-font-size);
#   font-weight: 600;
#   margin: 0.8em 0 0.4em;
# }
#
# .body-visualization > :first-child {
#   margin-top: 0;
# }
#
# .body-visualization > :first-child > h3 {
#   margin-top: 0;
# }
#
# /* Style of the main element containing all the input sentences */
# .line-style {
#   display: flex;
#   flex-wrap: wrap;
#   max-width: 100%;
#   /* line-height: 1.5em; */
#   padding-left: 1em;
#   margin-bottom: 0.2em;
# }
#
# /* Common style for all the words displayed (inputs, outputs, concepts) */
# .common-word-style {
#   font-family: var(--visualization-font-family) !important;
#   font-weight: inherit;
#   font-style: inherit;
#   font-size: var(--visualization-token-font-size);
#   padding: 0;
#   margin-right: 0.2em;
#   white-space: pre-wrap;
#   border-radius: 0.5em;
#   background-color: transparent;
#   border: 0px solid transparent;
#   outline: 1px solid transparent;
#   color: var(--text-color);
#   z-index: 0;
# }
#
# /*
# * Styles of the highlighted words with attribution colors: the inputs and some of the outputs.
# */
# .highlighted-word-style {
#   position: relative;
#   /* mandatory for the tooltip to be positioned correctly */
# }
#
# /* Highlighted words tooltips style */
# .highlighted-word-style .tooltiptext {
#   visibility: hidden;
#   text-align: center;
#   padding: 0.2em 0.45em;
#   border-radius: 0.5em;
#   white-space: nowrap;
#   font-family: var(--visualization-font-family);
#   font-size: var(--visualization-tooltip-font-size);
#   line-height: 1.2;
#   color: #222;
#   background-color: #e6e6e6;
#   /* Position of the tooltip w/r to the parent element */
#   position: absolute;
#   z-index: 1;
#   left: 50%;
#   bottom: 125%;
#   transform: translateX(-50%);
# }
#
# .highlighted-word-style .tooltiptext::after {
#   content: "";
#   position: absolute;
#   z-index: 1;
#   top: 100%;
#   /* Triangle at the bottom of the tooltip */
#   left: 50%;
#   margin-left: -0.3em;
#   border-width: 0.3em;
#   border-style: solid;
#   border-color: #e6e6e6 transparent transparent transparent;
# }
#
# .highlighted-word-style:hover .tooltiptext {
#   visibility: visible;
# }
#
# /*
# * Style of the reactive/clickable elements.
# */
# .reactive-word-style:hover {
#   transform: scale(1.15);
#   box-shadow: 0 4px 8px rgba(0, 0, 0, 0.5);
# }
#
# /*
# * Style of the words (concepts & outputs) currently selected by the user.
# */
# .selected-style {
#   outline: 2px solid red !important;
# }
#
# .is-emphasized {
#   font-weight: 600;
# }
#
# .is-hidden {
#   display: none;
# }
#
# /*
# * Style of the concepts in the concept menu.
# */
# .concept-style {
#   margin-right: 0.75em;
#   padding-left: 0.25em;
#   padding-right: 0.25em;
#   outline: 2px solid transparent;
# }
#
# /*
# * Style of the class buttons/labels.
# */
# .class-style {
#   margin-right: 0.75em;
#   padding-left: 0.25em;
#   padding-right: 0.25em;
#   outline: 2px solid transparent;
#   cursor: pointer;
# }
#
# /*
# * Style for class buttons with colored backgrounds (default multi-class view)
# */
# .class-style-colored-border {
#   outline-width: 2px;
#   outline-style: solid;
# }
#
# </style><script>
# (function () {
#     /**
#      * StateManager - Manages visualization state and transitions
#      */
#     window.StateManager = class StateManager {
#         constructor() {
#             this.activatedClassId = null;
#             this.selectedClassId = null;
#             this.currentOutputId = null;
#             this.selectedOutputId = null;
#         }
#
#         /**
#          * Set the active class (on hover)
#          * @param {number|null} classId - The class ID to activate
#          * @returns {object} What changed: { classChanged: boolean }
#          */
#         setActiveClass(classId) {
#             const changed = this.activatedClassId !== classId;
#             this.activatedClassId = classId;
#             return { classChanged: changed };
#         }
#
#         /**
#          * Toggle the selected class (on click)
#          * @param {number} classId - The class ID to toggle
#          * @returns {object} What changed: { classChanged: boolean, wasDeselected: boolean }
#          */
#         toggleSelectedClass(classId) {
#             const wasSelected = this.selectedClassId === classId;
#             if (wasSelected) {
#                 this.selectedClassId = null;
#                 this.activatedClassId = null;
#             } else {
#                 this.selectedClassId = classId;
#                 this.activatedClassId = classId;
#             }
#             return { classChanged: true, wasDeselected: wasSelected };
#         }
#
#         /**
#          * Restore active class to selected class (on mouse out)
#          * @returns {object} What changed: { classChanged: boolean }
#          */
#         restoreSelectedClass() {
#             const changed = this.activatedClassId !== this.selectedClassId;
#             this.activatedClassId = this.selectedClassId;
#             return { classChanged: changed };
#         }
#
#         /**
#          * Set the active output (on hover)
#          * @param {number|null} outputId - The output ID to activate
#          * @param {boolean} resetClass - Whether to reset class selection
#          * @returns {object} What changed: { outputChanged: boolean, classChanged: boolean }
#          */
#         setActiveOutput(outputId, resetClass = false) {
#             // Do not override a selected output on hover.
#             if (this.selectedOutputId !== null && this.selectedOutputId !== outputId) {
#                 return { outputChanged: false, classChanged: false };
#             }
#             const outputChanged = this.currentOutputId !== outputId;
#             const classChanged = resetClass && (this.activatedClassId !== null || this.selectedClassId !== null);
#
#             this.currentOutputId = outputId;
#             if (resetClass) {
#                 this.activatedClassId = null;
#                 this.selectedClassId = null;
#             }
#
#             return { outputChanged, classChanged };
#         }
#
#         /**
#          * Toggle the selected output (on click)
#          * @param {number} outputId - The output ID to toggle
#          * @param {boolean} resetClass - Whether to reset class selection
#          * @returns {object} What changed: { outputChanged: boolean, classChanged: boolean, wasDeselected: boolean }
#          */
#         toggleSelectedOutput(outputId, resetClass = false) {
#             const wasSelected = this.selectedOutputId === outputId;
#             const outputChanged = true;
#
#             if (wasSelected) {
#                 this.selectedOutputId = null;
#                 this.currentOutputId = null;

# %% [markdown]
# ## 2. Class-wise n-gram concept interpretation
#
# In the global approach above, we decompose the activations of the **entire** dataset, producing k concepts shared across all classes. Here, we take a different approach: for each class, we select only the data points predicted as that class, and decompose **their activations separately**.
#
# This yields **k concepts per class**, each capturing patterns specific to that class. For example, in a sentiment analysis task, a "joy" class might have concepts related to celebration, gratitude, or humor, while a "sadness" class might have concepts related to loss, loneliness, or disappointment.
#
# The steps are the same as before (decompose, interpret with n-grams, compute importance), but repeated independently for each class. The model split and CLS token activations computed earlier are reused — only the decomposition and interpretation are class-specific.

# %%
concept_explainers = {}
concept_interpretations = {}
concept_importances = {}

# iterate over classes
for target, class_name in enumerate(classes_names):
    # ----------------------------------------------------------------------------------------------
    # 2. construct the dataset of activations (extract the ones related to the class)
    indices = (activations["predictions"] == target).nonzero(as_tuple=True)[0]
    class_wise_inputs = [inputs[i] for i in indices]
    class_wise_activations = {k: v[indices] for k, v in activations.items()}

    if len(indices) == 0:
        print(f"\nClass: {class_name} — no samples predicted, skipping.")
        continue

    # ----------------------------------------------------------------------------------------------
    # 3. train concept model
    concept_explainers[target] = SemiNMFConcepts(model_with_split_points, nb_concepts=20, device="cuda")
    concept_explainers[target].fit(class_wise_activations)

    # ----------------------------------------------------------------------------------------------
    # 4. get the k-ngram-words activating the most the concept
    topngram_inputs_method = TopKInputs(
        concept_explainer=concept_explainers[target],
        k=15,
        activation_granularity=granularity,
        use_unique_words=5, # 5-grams words to illustrate each concept
        unique_words_kwargs={
            "count_min_threshold": round(len(inputs) * 0.002),
            "lemmatize": True,
            "words_to_ignore": [],
        },
    )
    concept_interpretations[target] = topngram_inputs_method.interpret(
        inputs=inputs,
        concepts_indices="all",
    )

    # ----------------------------------------------------------------------------------------------
    # 5. compute concepts importance
    gradients = concept_explainers[target].concept_output_gradient(
        inputs=class_wise_inputs,
        targets=[target],
        activation_granularity=granularity,
        concepts_x_gradients=True,
        batch_size=8,
    )

    concept_importances[target] = torch.stack(gradients, axis=0).squeeze().abs().mean(dim=0)

    important_concept_indices = torch.argsort(concept_importances[target], descending=True).tolist()

    print(f"\nClass: {class_name}")
    for concept_id in important_concept_indices[:5]:
        ngrams = concept_interpretations[target].get(concept_id)
        importance = concept_importances[target][concept_id].item()
        words = list(ngrams.keys()) if ngrams is not None else []
        print(f"\timportance: {round(importance, 3)},\tconcept {concept_id},\ttopk ngrams: {words}")
# Out:
# Class: admiration
# 	importance: 0.123,	concept 9,	topk ngrams: [', thanks for', 'thanks for the', 'thanks for', 'thanks !', 'thanks', 'thank you !', 'thank you so', '. thanks for', 'thank you so much', '. thank you', 'thank you for', ', thanks', 'thank you .', 'thanks ,', ', thank you']
# 	importance: 0.09,	concept 12,	topk ngrams: ['thanks for the', ', thanks for', 'thanks', '. thanks for', 'thanks for', 'thanks ,', 'thanks !', ', thanks', 'thanks .', '. thanks', ', thank you', 'thank you so much', 'thank you for', 'thank you so', '. thank you']
# 	importance: 0.081,	concept 1,	topk ngrams: ['new year', 'his', 'job', 'voice', 'body', 'work', 'he ’ s', 'i appreciate', 'name ] ha', 'appreciate', 'him a', 'name ] ,', 'brother', 'service', 'work .']
# 	importance: 0.069,	concept 3,	topk ngrams: ['my favorite', 'favorite', 'loved', 'hope', 'i wish', '. i hope', 'i hope', 'surprised', 'awesome', 'awesome .', 'favourite', 'the best', 'i hope you', 'enjoy', 'expect']
# 	importance: 0.051,	concept 0,	topk ngrams: ['please', 'least', 'the only', 'the only one', 'like this', 'like he', 'only', 'clearly', 'since', 'except', 'only one', 'especially', ', not', 'i ’ m not', 'honestly']
#
# Class: amusement
# 	importance: 0.085,	concept 2,	topk ngrams: ['he ha', "! ''", '] !', 'name ] ha', 'work .', '’ s a', '! i', '! ! ! ! !', 'he ’ s', 'yeah i', '! ! ! !', 'to me .', '] .', 'yeah', 'she ’']
# 	importance: 0.076,	concept 16,	topk ngrams: ['tell', 'few', '’ re', '....', 'a few', '...', '.....', 'couple', 'sometimes', 'hair', 'even', 'though .', 'doesn ’', 'bro', 'i ’ ll']
# 	importance: 0.073,	concept 1,	topk ngrams: ['everyone', 'the game', 'i should', 'life', 'plan', '. i just', 'one is', 'it just', 'original', 'he is', 'omg', 'the first', 'story', 'i always', 'brother']
# 	importance: 0.071,	concept 13,	topk ngrams: ['awesome', 'favorite', 'awesome .', 'appreciate', 'i appreciate', 'my favorite', 'cute', 'i like', 'love it .', 'i love this', 'like you', 'love', 'i love the', 'is awesome', 'love to']
# 	importance: 0.07,	concept 6,	topk ngrams: ['[ name ] !', 'like he', '] , [', '[ name ] .', '[', 'about [ name', '. [ name ]', 'i love the', 'love it .', '] and [', 'and [ name ]', '[ name ] and', 'like [ name', 'like [', 'like you']
#
# Class: anger
# 	importance: 0.078,	concept 4,	topk ngrams: ['damn ,', 'you will', 'try', 'i will', 'i hope', 'omg', 'i always', 'may', 'glad', 'heart', 'myself', 'boy', 'beat', 'glad to', 'i ’ ll']
# 	importance: 0.076,	concept 17,	topk ngrams: ['woman', 'nobody', 'no idea', 'child', 'you have a', 'this is a', 'damn', 'person .', 'mother', 'dead', 'the same thing', 'no one', "n't believe", 'suck', 'people who']
# 	importance: 0.068,	concept 19,	topk ngrams: ['[ name ] is', ', [ name ]', '[ name ] would', '[ name ] ha', '[ name ]', 'happens', '[ name ] .', '[ name ] !', '[ name ] wa', 'surprised', 'think', '[ name ] ?', 'the [ name ]', 'damn', 'think of']
# 	importance: 0.064,	concept 6,	topk ngrams: ['she ’', '[ name ] ha', 'dude', '] , [ name ]', 'city', 'it ’', '[ name ] !', ', [ name ]', '] ha', ', it ’', '] , [ name', 'the same thing', '[ name ]', 'name ] , [ name', 'the [ name ]']
# 	importance: 0.059,	concept 10,	topk ngrams: ["n't think", '’ t think', 't think', "n't believe", 'think', 'matter', 'surprised', 'why', 'reading', 'attention', 'job', 'think it', 'i think', 'don ’ t think', 'i don ’ t']
#
# Class: annoyance
# 	importance: 0.091,	concept 13,	topk ngrams: ['. thank you', 'thank you', 'thank you .', 'thank you so', '. thank', 'thank you !', 'thank you so much', 'thank you for', 'thank', ', thank you', ', thank', 'thanks .', 'thanks ,', 'thanks for', 'awful']
# 	importance: 0.075,	concept 1,	topk ngrams: ['i think it', "that 's the", '. thanks', "that 's", 'that i', 'that would be', 'but it', ', thanks', 'thanks ,', 'that ’ s a', 'him .', "that 's a", 'to me .', 'that is', 'this one']
# 	importance: 0.075,	concept 5,	topk ngrams: ['. thanks', ', thanks', '. thanks for', 'thanks', 'thanks .', 'thanks for the', 'thanks ,', ', thanks for', ', thank you', 'thanks !', 'thanks for', 'thank you .', '. thank you', 'thank you for', 'thank you so']
# 	importance: 0.066,	concept 4,	topk ngrams: ['[ name ] !', '>', '[ name ] ha', '] , [ name ]', 'a [ name ]', 'it ’', 'so .', '[ name ] .', ', [ name ]', '”', '“', ')', '’', '. [ name ]', 'i don ’ t']
# 	importance: 0.055,	concept 0,	topk ngrams: ['i should', 'got ta', 'chance', 'can', 'run', 'should have', 'check', 'should', 'stand', 'gon', 'should be', 'put', 'felt', 'ago', 'take']
#
# Class: approval
# 	importance: 0.082,	concept 4,	topk ngrams: ['name ] would', '[ name ] would', 'i saw', "would n't", 'watched', 'i had', 'i would', 'they could', 'will be', 'will get', 'name ] , [ name', 'have no', '[ name ] ha', "could n't", 'made']
# 	importance: 0.075,	concept 17,	topk ngrams: ['i hope you', 'hope you', 'i hope', '. i hope', 'hope', 'care about', 'i wish', 'i agree', 'helped', 'will be', 'worry', 'i want to', 'you will', 'will get', 'help']
# 	importance: 0.075,	concept 8,	topk ngrams: ['least', 'at least', 'i thought it', 'honestly', 'the only', 'i hope you', 'will be', '’ t think', "n't think", 'entire', "it 's not", 'only', 'it ’ s not', "i did n't", 'wish']
# 	importance: 0.075,	concept 11,	topk ngrams: ['love it .', 'i love the', 'i love it', 'love', 'i agree', 'i love this', 'love it', 'i love', 'love this', 'love the', 'i like', 'like you', 'close', 'one .', 'relationship']
# 	importance: 0.062,	concept 5,	topk ngrams: ['sharing', 'worse', 'confused', '’ s what', 'isn', 'why', 'what', '] ?', 'not even', 'didn', 'what ?', 'didn ’ t', ', what', 'even if', 'you ?']
#
# Class: caring
# 	importance: 0.081,	concept 7,	topk ngrams: ['i hope you', 'hope you', 'hope', 'i hope', '. i hope', 'i wish', 'disgusting', 'wish', 'so sorry', 'worry', 'worried', 'hopefully', 'so happy', 'care about', 'hoping']
# 	importance: 0.074,	concept 15,	topk ngrams: ['like you', 'like it', 'like he', 'help', 'like the', 'like', 'like this', 'to you', 'to you .', 'what you', 'like a', 'especially', 'like that', 'love the', 'favourite']
# 	importance: 0.068,	concept 2,	topk ngrams: ['hope', 'i hope', '. i hope', 'i hope you', 'enjoy', 'worry', 'so happy', 'nothing', 'happy', 'loved', 'myself', 'hope you', 'it out', 'please', 'i agree']
# 	importance: 0.067,	concept 3,	topk ngrams: ['it ?', 'this ?', 'right ?', 'you ?', '[ name ] ?', 'what ?', 'name ] ?', '? ! ?', '? that', '! ?', '? !', '? i', '] ?', '? it', '? ?']
# 	importance: 0.067,	concept 14,	topk ngrams: ['so sorry', 'sorry for', 'disgusting', "would n't", 'unfortunately', "you ca n't", 'sorry', "have n't", "could n't", 'stupid', 'can ’ t', 'worried', 'i can ’ t', "i ca n't", 'terrible']
#
# Class: confusion
# 	importance: 0.092,	concept 19,	topk ngrams: ['afraid', 'i wish', '. [ name', 'support', "do n't", "is n't", 'welcome', 'wish', 'effort', 'a [', '. [ name ]', '. so', 'source', "n't be", 'i hope']
# 	importance: 0.071,	concept 10,	topk ngrams: ['think', 'thought it', 'i think i', 'think you', 'thought', 'i hate', 'i thought', 'i think', 'i thought it', 'thinking', 'think that', 'seeing', 'the fuck', 'stupid', 'think it']
# 	importance: 0.063,	concept 6,	topk ngrams: ['i wish', 'helped', 'i hope you', 'hope you', 'hope', 'luck', 'that ’ s what', 'worried', 'great', 'wish', "wa n't", 'i hope', 'idea .', 'good .', '. i hope']
# 	importance: 0.06,	concept 12,	topk ngrams: ['disgusting', 'fucking', 'fuck', 'stupid', 'out .', 'the worst', 'horrible', 'wrong .', 'suck', 'shit', 'too .', 'dead', 'the fuck', 'worst', 'too !']
# 	importance: 0.059,	concept 11,	topk ngrams: ['i wish', 'wish', 'wish i', 'hope you', 'hope', 'i hope you', '. i hope', 'i hope', 'hoping', 'i want to', 'helped', 'worry', 'i want', 'care about', 'hopefully']
#
# Class: curiosity
# 	importance: 0.118,	concept 10,	topk ngrams: ['do not', '. not', 'ask', 'didn', 'should', 'kill', 'isn', 'without', 'did not', 's not', 'got a', 'doesn ’ t', '>', 'isn ’ t', 'doesn']
# 	importance: 0.084,	concept 9,	topk ngrams: ['[ name ] ha', 'the [', '[ name ] !', '[', 'the [ name ]', '[ name ] , [', '[ name ]', 'like [ name', 'my [ name ]', 'with [ name ]', '[ name ] and [', '] , [', 'the [ name', 'with [', 'of [ name ]']
# 	importance: 0.069,	concept 5,	topk ngrams: ['surprised', 'nah', 'throw', 'wish', 'make', 'sad', 'hopefully', 'next', 'worry', 'ask', 'thank', 'wait', 'coming', 'sorry', 'watching']
# 	importance: 0.066,	concept 2,	topk ngrams: ['i wish', 'wish', 'how', 'why', 'wish i', 'afraid', 'hope', 'how to', 'surprised', 'the fuck', 'how much', "i did n't", 'i used', '. i hope', 'i hope']
# 	importance: 0.065,	concept 7,	topk ngrams: ['thank you so', ', thank', 'thank you .', 'thank you so much', 'thank you for', 'thank you !', 'thank you', '. thank', '. thank you', ', thank you', 'thank', 'thanks ,', 'thanks for', ', thanks', 'thanks .']
#
# Class: desire
# 	importance: 0.101,	concept 11,	topk ngrams: ['remember', ', we', ', just', ', it ’', ', and i', 'i mean', 'to me', 'got ta', 'hand', ', i ’', 'i dont', ', it', '>', ', you', 'wait']
# 	importance: 0.096,	concept 16,	topk ngrams: ["n't want", 'making', 'stay', 'away', 'stupid', 'move', 'horrible', 'worse', 'fuck', 'sharing', 'the worst', 'cold', 'didn ’ t', "they 're", 'unfortunately']
# 	importance: 0.093,	concept 9,	topk ngrams: ['my favorite', 'favorite', 'i love it', 'love to', 'i love this', 'love it .', 'i love the', 'love it', 'awesome', 'love', 'favourite', 'i love', 'like you', 'love this', 'awesome .']
# 	importance: 0.069,	concept 14,	topk ngrams: ['expect', 'helped', 'something', 'it wa a', 'cut', 'i want to', 'it wa', 'i want', 'loved', 'i wa', 'didn ’ t', 'experience', 'awesome', '. i hope', 'starting']
# 	importance: 0.064,	concept 5,	topk ngrams: ['original', 'i hope you', 'absolute', '. thanks', 'i hope', 'awesome', 'cut', '. i hope', 'appreciate', 'welcome', 'i will', 'i think i', 'good luck', 'great', 'awesome .']
#
# Class: disappointment
# 	importance: 0.079,	concept 15,	topk ngrams: ['good .', 'lmao', 'good', 'appreciate', 'cute', 'i appreciate', 'pretty', 'great', 'good luck', 'the best', 'haha', 'wow', 'sweet', 'luck', 'awesome .']
# 	importance: 0.072,	concept 5,	topk ngrams: ['i thought it', 'surprised', 'how', 'what is', 'what', 'what i', 'confused', 'lol .', 'idea .', 'think', 'how it', 'too .', 'something', 'i think i', '. what']
# 	importance: 0.069,	concept 17,	topk ngrams: ['least', ', just', 'at least', 'ago', 'please', ', too', 'free', 'strong', 'idea', 'hit', 'idea .', 'late', 'the only', 'cut', 'whole']
# 	importance: 0.065,	concept 6,	topk ngrams: ['[ name ] ?', 'name ] ?', 'i don', 'yes !', '. he', '. so', 'are so', 'are', 'so', '. they', '] ?', '..', 'have to', 'they did', 'we']
# 	importance: 0.062,	concept 4,	topk ngrams: ['unfortunately', 'sorry for', 'nothing', 'worried', 'so sorry', 'afraid', 'something', 'loved', 'surprised', 'awful', 'i hope you', 'terrible', 'sorry', 'how it', 'expect']
#
# Class: disapproval
# 	importance: 0.105,	concept 1,	topk ngrams: ['care about', 'appreciate', 'i appreciate', 'good luck', 'i hope you', 'good .', 'hope you', 'welcome', '? it', '? i', '? that', 'help', 'support', 'i hope', 'hope']
# 	importance: 0.06,	concept 13,	topk ngrams: ['] ?', 'wrong', 'ask', 't', 'ta', 'already', 'you ?', '? that', '? i', 'didn', 'sad', 'this ?', 'loss', 'only', '! ? !']
# 	importance: 0.06,	concept 4,	topk ngrams: ['[ name ] ?', 'not .', 'you can', "you 'll", 'not be', 'you should', '[ name ] would', '[ name ] is', 'you will', 'only', 'you are', 'only one', 'you think', "you do n't", 'you were']
# 	importance: 0.057,	concept 9,	topk ngrams: ['remember', 'example', ', we', 'especially', 'except', 'than', 'than the', 'bet', ', you', 'want', 'for that', 'can ’', ', even', ', if', 'that ,']
# 	importance: 0.057,	concept 7,	topk ngrams: ['it !', 'i really', 'it just', 'it is', 'it .', '. i just', 'it', 'i think it', 'it ?', 'i don ’', 'him .', 'it ’', ', but it', 'i just', ', just']
#
# Class: disgust
# 	importance: 0.09,	concept 8,	topk ngrams: ['name ] ?', '[ name ] ?', 'right ?', 'it ?', 'what ?', '] ?', 'you ?', 'this ?', '! ?', '? ! ?', '? it', '? i', '?', '! ? !', '? ?']
# 	importance: 0.08,	concept 19,	topk ngrams: ['not .', 'sorry for', 'sorry', 'so sorry', 'right ?', 'out .', 'not', '? that', 'this ?', 'and not', 'nothing', 'not sure', '? i', 'terrible', 'you ?']
# 	importance: 0.072,	concept 2,	topk ngrams: ['the last', 'job', 'season', 'i would', 'biggest', 'i never', 'the whole', 'different', 'will be', 'they could', 'it would', 'i had', 'the same', 'i can ’ t', 'it look']
# 	importance: 0.067,	concept 1,	topk ngrams: ['[ name ] ?', 'name ] ?', '] ?', 'right ?', 'what ?', 'you ?', '?', '! ?', '? that', '? i', '? ?', '? it', 'this ?', '? ! ?', 'it ?']
# 	importance: 0.062,	concept 12,	topk ngrams: ['unfortunately', 'anyone', "you 've", "'m not", "ca n't", "wa n't", "i 'm not", 'want to', 'not a', "'s not", 'not .', 'i want to', "if you do n't", "'re not", 'i can ’ t']
#
# Class: embarrassment
# 	importance: 0.114,	concept 16,	topk ngrams: ['awesome .', 'awesome', 'is awesome', 'amazing', 'appreciate', 'i appreciate', 'cute', 'this sub', 'great', 'surprised', 'a great', 'the best', 'my favorite', 'helped', 'this']
# 	importance: 0.092,	concept 11,	topk ngrams: [', or', 'i will', 'i should', 'kid', 'will', ': (', 'i ca', 'i hate', 'died', 'i got', 'think', 'felt', "'d be", 'i would', 'i agree']
# 	importance: 0.084,	concept 6,	topk ngrams: ['think', 'didn ’', 'i hate', '. not', 'i mean', 'doesn ’ t', 'ball', 'mean', ', if', 'do not', '. if', 'remember', 'far', 'clearly', 'i think']
# 	importance: 0.082,	concept 19,	topk ngrams: ['name ] and [', 'to [ name', 'about [ name', 'name ] and [ name', 'by [ name', 'with [ name', 'of [ name', 'a couple', 'by [ name ]', '. [ name', 'name ] , [', 'pick', 'name ] , [ name', 'name ] and', 'with [ name ]']
# 	importance: 0.067,	concept 4,	topk ngrams: ["ca n't", 'honestly', "i ca n't", 'not even', 'not a', 'only one', "what 's", "i do n't", "have n't", "wa n't", 'not to', 'nothing', "it 's not", 'not', "you ca n't"]
#
# Class: excitement
# 	importance: 0.097,	concept 13,	topk ngrams: ['what ?', '? i', 'it ?', 'right ?', '? that', '? it', '! ?', 'this ?', '! ? !', '? ?', '? ! ?', '? !', 'you ?', '?', 'name ] ?']
# 	importance: 0.085,	concept 3,	topk ngrams: ['appreciate', 'my favorite', 'i wish', 'wow ,', 'happy', 'i appreciate', 'so happy', 'luck', 'good luck', 'wow', 'enjoy', 'i want to', 'favorite', 'will be', 'the best']
# 	importance: 0.084,	concept 2,	topk ngrams: ['point .', 'deep', 'starting', 'happens', 'area', 'seriously', 'high', 'day .', 'picture', 'video', 'sound like', 'and you', 'personally', 'above', 'with you']
# 	importance: 0.08,	concept 18,	topk ngrams: ['sorry', 'sorry for', 'why', 'disgusting', 'what ?', '? that', '? i', 'so sorry', '? ?', 'wow', '?', 'right ?', 'terrible', '] ?', 'fucking']
# 	importance: 0.077,	concept 4,	topk ngrams: ['good .', '. [', "i did n't", 'cute', 'honestly', 'a [', '. good', "wa n't", 'sweet', 'good luck', "i do n't", 'i can ’ t', "'re not", 'good', "would n't"]
#
# Class: fear
# 	importance: 0.162,	concept 8,	topk ngrams: ['so sorry', 'sorry for', 'disgusting', 'sorry', 'surprised', 'stupid', 'unfortunately', 'nothing', "ca n't", "is n't", "i ca n't", "wa n't", 'what ?', 'you ?', 'name ] ?']
# 	importance: 0.093,	concept 16,	topk ngrams: ['welcome', 'heart', 'so happy', 'care about', 'enjoy', 'curious', 'excited', 'help', 'effort', 'wow ,', 'living', 'you so much', 'super', 'attention', ', or']
# 	importance: 0.077,	concept 2,	topk ngrams: ['over the', 'by the', 'up the', 'with that', 'curious', 'with this', 'for the', 'that', 'with the', 'of it', 'of his', 'with it', 'of the', 'of course', 'about the']
# 	importance: 0.071,	concept 7,	topk ngrams: ['isn ’ t', 'the fuck', 'everyone', 'isn', 'no idea', 'everything', "i 'm going", 'damn ,', 'being a', 'nobody', 'i hate', 'tbh', 'damn', 'party', 'someone']
# 	importance: 0.062,	concept 19,	topk ngrams: ['not .', "i did n't", 'i don ’ t', "'s not", 'not be', "i do n't", "it 's not", "'re not", 'i can ’ t', "n't have", '’ t think', 'it ’ s not', "i 'm not", 'not sure', "i ca n't"]
#
# Class: gratitude
# 	importance: 0.1,	concept 16,	topk ngrams: ['welcome', 'beautiful', 'appreciate', 'good', 'awesome', 'great', 'awesome .', 'i appreciate', 'is awesome', 'good .', 'pretty', 'good luck', 'cute', 'original', 'least']
# 	importance: 0.08,	concept 0,	topk ngrams: ['] and [ name', 'life .', 'to [ name ]', '[ name ] !', '[ name ] would', '. [ name ]', 'my [ name ]', ". it 's", '!', 'about to', 'using', '[ name', 'and [ name ]', 'with [ name ]', 'to [']
# 	importance: 0.069,	concept 17,	topk ngrams: ['i hope you', 'care about', 'i wish', 'helped', 'hope you', 'sorry for', 'i hope', 'good luck', '. i hope', 'so sorry', 'hope', 'wish', 'wish i', 'appreciate', 'hopefully']
# 	importance: 0.059,	concept 3,	topk ngrams: ['right ?', 'good .', 'sorry', '. thank you', 'it ?', 'you ?', 'this ?', 'thank you .', 'sorry for', 'thank you', 'thank you so', 'i appreciate', 'so sorry', '? that', 'great']
# 	importance: 0.057,	concept 19,	topk ngrams: ['thank you !', 'thank', 'thank you', 'thank you .', 'thank you for', 'thank you so', '. thank you', ', thank', '. thank', 'thank you so much', ', thank you', 'appreciate', 'i appreciate', 'wow ,', 'confused']
#
# Class: grief — no samples predicted, skipping.
#
# Class: joy
# 	importance: 0.073,	concept 8,	topk ngrams: ['living', 'change', 'happy', 'so happy', 'entire', 'situation', 'new', 'wife', ')', 'absolute', 'working', 'couple', 'explain', 'life', 'weird']
# 	importance: 0.073,	concept 18,	topk ngrams: ["have n't", "n't think", 'shit', "i did n't", 't think', "'re not", "n't have", 'nothing', "n't believe", "i ca n't", "it 's not", 'no .', "'s not", "wa n't", "n't be"]
# 	importance: 0.067,	concept 14,	topk ngrams: ['my favorite', 'favorite', 'good luck', 'good', 'the best', 'welcome', 'cute', 'is awesome', 'appreciate', 'great', 'awesome', 'best', 'awesome .', 'good .', 'i appreciate']
# 	importance: 0.063,	concept 1,	topk ngrams: ['disgusting', 'awful', 'a great', 'loved', 'stupid', 'a good', 'what you', 'lmao', 'the fuck', 'haha', 'interesting', 'confused', 'a fucking', 'enjoy', 'what the']
# 	importance: 0.063,	concept 7,	topk ngrams: ['i can ’', 'luck', 'hit', 'oh ,', 'used to', 'laugh', 'better .', 'high', 'oh', 'i can', 'joke', 'strong', "wa n't", 'a joke', 'help']
#
# Class: love
# 	importance: 0.084,	concept 12,	topk ngrams: ['[ name ] would', '[ name ] is', 'the [ name ]', 'a [ name ]', '[ name ]', '[ name ] wa', 'like [ name ]', '[ name ] ha', 'of [ name ]', 'the [ name', '[ name ] !', 'like [ name', '[ name', 'you will', 'a [ name']
# 	importance: 0.078,	concept 1,	topk ngrams: ['sorry', 'sorry for', 'so sorry', "i 'm not", "it 's not", "i do n't", 'it ’ s not', 'i ’ m not', "'s not", 'not be', "i ca n't", "'re not", "i did n't", 'not sure', 'i don ’ t']
# 	importance: 0.074,	concept 16,	topk ngrams: ['my favorite', 'favorite', 'the best', 'awesome', 'awesome .', 'great', 'thanks .', 'is awesome', '. thanks', 'thanks ,', 'thanks', ', thanks', '. thanks for', 'thanks for the', 'thanks !']
# 	importance: 0.074,	concept 6,	topk ngrams: ['. thanks for', 'thanks for the', 'thanks', ', thanks for', 'thanks !', 'thanks for', 'thanks ,', 'thanks .', 'thank you for', '. thanks', ', thanks', 'thank you so', 'thank', 'thank you so much', ', thank you']
# 	importance: 0.068,	concept 4,	topk ngrams: ["'ve been", 'haha', 'love it .', 'please', 'will be', 'honestly', 'i can ’ t', '[ name ] ha', 'like [ name ]', "you 've", 'sweet', 'i thought it', 'love it', 'oh', 'have been']
#
# Class: nervousness
# 	importance: 0.106,	concept 14,	topk ngrams: ['fuck', 'afraid', 'terrible', 'worst', 'nothing', 'that would', 'i hate', 'loss', 'story', 'entire', 'when it', 'hurt', 'made', 'why', 'away']
# 	importance: 0.07,	concept 6,	topk ngrams: ['check', 'house', 'explain', 'trying to', 'me .', 'attack', 'that would', 'reddit', 'there .', 'government', '. i ’', 'story', 'the guy', 'deal', 'him .']
# 	importance: 0.067,	concept 15,	topk ngrams: ['i had', 'i could', 'expect', 'i wish', 'lol ,', 'kid', 'wow ,', 'ha been', 'anyone', 'stupid', "it 's not", 'wow', 'amazing', 'i can', 'i thought']
# 	importance: 0.064,	concept 11,	topk ngrams: ['effort', 'job', 'experience', 'name ] .', 'name ] ha', "that 's a", 'advice', 'care about', 'work', ", that 's", 'open', "'m going", 'work .', 'starting', 'posted']
# 	importance: 0.063,	concept 0,	topk ngrams: ['made', '. i ’', 'used', 'starting', 'helped', 'difference', 'know ,', 'make the', 'a good', 'idk', 'much .', 'glad to', "'' .", 'against', '. i ’ m']
#
# Class: optimism
# 	importance: 0.114,	concept 7,	topk ngrams: ['i hope', '. i hope', 'hope', 'sweet', 'i hope you', 'loved', 'the kid', 'support', 'fine', 'the best', 'idea', 'plan', 'lol ,', 'lol', 'love to']
# 	importance: 0.094,	concept 9,	topk ngrams: ['[ name ] ha', ", it 's", 'my [ name ]', '[ name ] !', 'name ] and [ name', '[ name ] would', 'the [ name ]', 'my [ name', '] , [ name ]', '[ name ] is', ', [ name ]', '] , [ name', 'me .', 'honestly', '] and [ name ]']
# 	importance: 0.079,	concept 8,	topk ngrams: ['thanks', '. thanks for', 'thanks for the', 'thanks ,', ', thanks', ', thanks for', 'thanks !', 'thanks for', '. thanks', 'thanks .', 'thank you so much', ', thank you', 'thank you so', 'thank you for', '. thank you']
# 	importance: 0.062,	concept 2,	topk ngrams: ['forgot', 'will be', 'will get', 'will', 'leave', 'felt', 'care about', 'died', 'start', 'take', "n't believe", 'back to', 'i should', 'i will', 'took']
# 	importance: 0.06,	concept 11,	topk ngrams: ['thank you .', 'thanks !', 'thank you so', ', thank you', 'thank you so much', '. thank you', 'thanks ,', 'thank you !', 'thanks .', 'thanks for the', 'thank you for', 'thanks for', ', thanks for', 'thank you', 'thanks']
#
# Class: pride — no samples predicted, skipping.
#
# Class: realization
# 	importance: 0.083,	concept 10,	topk ngrams: ['right ?', 'what ?', 'this ?', '? i', '? that', '? !', 'you ?', 'stupid', 'it ?', '! ?', '? it', '! ? !', '? ?', '? ! ?', '?']
# 	importance: 0.069,	concept 12,	topk ngrams: ['not even', "n't even", 'too .', '.', '. what', 'not a', 'everything', 'all the', 'not the', 'everyone', "n't want", '. but', '. my', '. no', 'no idea']
# 	importance: 0.06,	concept 19,	topk ngrams: ['i appreciate', 'care about', 'is awesome', '. good', 'cute', 'good .', 'good luck', 'live in', 'guess', 'beautiful', 'wow ,', 'baby', 'try to', 'wow', 'early']
# 	importance: 0.057,	concept 5,	topk ngrams: ['sorry', 'i can ’ t', "you 've", '[ name ] ha', 'my [', 'i like', "i 'm not", 'wow ,', '[', "i 've", 'we can', 'i will', '. [', 'like you', 'i would']
# 	importance: 0.055,	concept 3,	topk ngrams: ['dude', 'me', 'it !', 'me .', ", it 's", ': (', ', it ’', 'name ] is', '] would', 'gon', '(', 'we are', 'is it', '] , [ name ]', 'man']
#
# Class: relief
# 	importance: 0.093,	concept 13,	topk ngrams: ['disgusting', "ca n't", 'problem .', '’ m so', "i 'm not", 'worry', 'living', 'so sorry', 'care about', 'unfortunately', 'heart', 'it ’ s not', "n't be", 'support', "is n't"]
# 	importance: 0.091,	concept 16,	topk ngrams: ['awesome .', 'pretty', 'awesome', 'huge', 'cute', 'enjoy', 'expect', 'hope you', 'lol', 'experience', 'a joke', 'you could', 'good .', 'kinda', 'lol .']
# 	importance: 0.073,	concept 17,	topk ngrams: ['problem .', 'support', 'living', 'heart', 'i dont', ', and i', 'vote', 'you need', 'deserve', 'her .', 'service', 'i had', 'a joke', 'ha been', "'ll be"]
# 	importance: 0.068,	concept 6,	topk ngrams: ['worry', "i 've", 'amazing', 'i like', 'like he', '’ t think', 'working', 'work .', '. i hope', 'appreciate', "n't know", 'cut', 'the game', 'welcome', 'wow ,']
# 	importance: 0.058,	concept 7,	topk ngrams: ['so happy', 'it ’ s', 'joke', 'worried', 'oh', 'the kid', 'wow', 'ha been', 'heart', 'kid', 'well .', 'lmao', 'haha', "n't be", '’ t']
#
# Class: remorse
# 	importance: 0.096,	concept 1,	topk ngrams: ['thank you for', '. thank', ', thank you', 'thank you so much', '. thank you', '. thanks', 'thanks .', 'thank you .', 'thank you', 'love this', 'thank', 'thank you so', ', thank', 'i love it', 'thank you !']
# 	importance: 0.095,	concept 4,	topk ngrams: [', or', ', my', ', and', ", it 's", 'i will', ', we', 'could', ', it ’ s', 'alright', ',', 'my life', 'me ,', ', i ’', 'might', 'that ’ s']
# 	importance: 0.075,	concept 2,	topk ngrams: ['even if', 'when they', 'when it', 'not even', 'when i', "if you do n't", 'when you', 'because you', 'when he', 'not .', 'feeling', 'because they', "n't even", 'them .', 'feel like']
# 	importance: 0.07,	concept 7,	topk ngrams: ['rude', 'sorry for', 'sorry', ', not', 'i ’ m not', "i 'm not", 'god', 'please', '(', 'full', '] , [ name ]', '] , [ name', 'ago', 'i will', "doe n't"]
# 	importance: 0.069,	concept 13,	topk ngrams: ['hope', 'i hope you', 'i hope', '. i hope', 'hope you', 'i wish', 'it wa', 'wish', 'curious', 'afraid', 'think', 'lol ,', 's what', 'thought', 'helped']
#
# Class: sadness
# 	importance: 0.133,	concept 19,	topk ngrams: ['excited', 'i mean', 'sound', ', he', 'wait', 'started', 'mean', 'should have', 'got', ', i', 'beat', 'said', 'time', 'day .', 'cat']
# 	importance: 0.084,	concept 0,	topk ngrams: ['i hope you', 'worry', '. i hope', 'wow', 'so happy', 'surprised', 'haha', 'hope you', 'worried', 'lmao', 'i hope', 'awesome', 'omg', 'pretty', 'beautiful']
# 	importance: 0.075,	concept 4,	topk ngrams: [', [ name', ', [', '[ name', 'for [', 'that [ name', 'that [', '] wa', '[', ': (', 'give', '[ name ] , [', 'into', '] , [', 'of [ name', 'for [ name']
# 	importance: 0.059,	concept 2,	topk ngrams: ['me .', 'lol .', 'i will', 'the kid', 'i can ’', 'past', 'wrong .', 'lol ,', 'problem .', 'oh', 'glad to', 'lol', 'my [', 'love to', 'laugh']
# 	importance: 0.055,	concept 10,	topk ngrams: ['i can ’ t', 'unfortunately', 'the only one', 'didn ’ t', 'honestly', 'especially', 'feel like', '(', 'like [ name', 'i feel', 'the only', 'i thought it', "'ve been", 'i had', 'feel']
#
# Class: surprise
# 	importance: 0.108,	concept 17,	topk ngrams: ['agree', '? that', 'mean', 'where', 'either', 'last', 'doesn ’ t', 'believe', 'doesn', 'i agree', '..', 'now .', 'now', 'back to', 'dont']
# 	importance: 0.094,	concept 16,	topk ngrams: ['why', ', what', 'what', 'is what', '. what', 'how', '’ s what', 'confused', 's what', 'sorry', 'what is', 'what i', 'how much', "what 's", '] ?']
# 	importance: 0.087,	concept 6,	topk ngrams: ['stupid', 'disgusting', 'terrible', 'fuck', 'the fuck', 'a fucking', 'nothing', 'worst', 'no ,', 'the worst', 'not sure', 'i hate', 'shit', 'dead', 'weird']
# 	importance: 0.082,	concept 8,	topk ngrams: ['disgusting', 'omg', 'fuck', 'fucking', 'stupid', 'dead', 'shit', 'cant', 'joke', 'afraid', 'dumb', 'expect', 'surprised', 'lol', 'suck']
# 	importance: 0.064,	concept 1,	topk ngrams: ['unfortunately', 'hopefully', 'sorry for', 'so sorry', 'sorry', 'i want', '”', 'i wish', '’', '[ name ] would', '“', '] , [', '. i wa', 'wish', 'read']
#
# Class: neutral
# 	importance: 0.112,	concept 4,	topk ngrams: ['would be', 'thought it', 'if we', 'would have', 'that .', 'because i', "if you do n't", 'did not', 'it ’ s not', "it 's not", 'if this', 'should be', 'think that', 'throw', "i did n't"]
# 	importance: 0.07,	concept 3,	topk ngrams: ['surprised', 'watching', 'disgusting', 'terrible', 'i agree', 'wish', 'thinking', 'worried', 'thought', 'idea .', 'the worst', 'horrible', '. i hope', 'i thought it', 'experience']
# 	importance: 0.062,	concept 1,	topk ngrams: ['sorry', 'so sorry', 'sorry for', 'i will', "n't be", "i 'm not", 'i ’ m not', "n't get", 'do not', 'i can ’ t', "'d be", 'i can ’', 'cat', 'i can', "i ca n't"]
# 	importance: 0.061,	concept 14,	topk ngrams: ["if you 're", 'if you do', 'if you', 'when you', 'if they', "if you do n't", 'when they', 'if we', 'even if', 'if this', 'if the', 'if she', 'when it', 'when i', 'because you']
# 	importance: 0.061,	concept 17,	topk ngrams: ['lol', 'a [ name ]', 'laugh', 'the [ name ]', 'funny', 'lol .', ', [ name ]', 'a joke', 'lmao', '[ name ] wa', 'lol ,', 'like [ name ]', 'that [ name ]', '[ name ]', 'joke']

# %%
plot_concepts(
    classes_names=classes_names,
    concepts_importances={
        classes_names[t]: concept_importances[t]
        for t in concept_importances
    },
    concepts_labels={
        classes_names[t]: {
            cid: list(ngrams.keys())
            for cid, ngrams in concept_interpretations[t].items()
            if ngrams is not None
        }
        for t in concept_interpretations
    },
    top_k=5,
)
# Out:
# <head><style>
# /*
# *   CSS styling for explanation visualizations
# */
#
# /* Light mode */
# :root {
#   --default-background-color: white;
#   --default-text-color: black;
#   --visualization-font-family: "IBM Plex Sans", "Fira Sans", "Segoe UI", sans-serif;
#   --visualization-font-size: 14px;
#   --visualization-token-font-size: 1.1em;
#   --visualization-heading-font-size: 1.15em;
#   --visualization-tooltip-font-size: 0.85em;
#   --visualization-line-height: 1.5;
# }
#
# /* Dark mode */
# @media (prefers-color-scheme: dark) {
#   :root {
#     --default-background-color: hsl(225, 10%, 15%);
#     --default-text-color: hsl(230, 10%, 85%);
#   }
# }
#
# :root {
#   /* Set the text color and background color depending on the current
#   * vscode theme if available, or on the current light/dark mode if in
#   * a browser
#   */
#   --background-color: var(--vscode-editor-background,
#       var(--default-background-color));
#   --text-color: var(--vscode-editor-foreground, var(--default-text-color));
#
#   --positive-color: #ff0000;
#   --negative-color: #0000ff;
#
#   /* Reversed colors  */
#   --reversed-background-color: var(--text-color);
#   --reversed-text-color: var(--background-color);
# }
#
# .body-visualization {
#   background-color: var(--background-color);
#   color: var(--text-color);
#   font-family: var(--visualization-font-family);
#   font-size: var(--visualization-font-size);
#   line-height: var(--visualization-line-height);
#   margin: 0;
#   padding: 0;
# }
#
# .body-visualization button,
# .body-visualization input,
# .body-visualization select,
# .body-visualization textarea {
#   font-family: var(--visualization-font-family);
#   font-size: inherit;
# }
#
# .body-visualization h3 {
#   font-size: var(--visualization-heading-font-size);
#   font-weight: 600;
#   margin: 0.8em 0 0.4em;
# }
#
# .body-visualization > :first-child {
#   margin-top: 0;
# }
#
# .body-visualization > :first-child > h3 {
#   margin-top: 0;
# }
#
# /* Style of the main element containing all the input sentences */
# .line-style {
#   display: flex;
#   flex-wrap: wrap;
#   max-width: 100%;
#   /* line-height: 1.5em; */
#   padding-left: 1em;
#   margin-bottom: 0.2em;
# }
#
# /* Common style for all the words displayed (inputs, outputs, concepts) */
# .common-word-style {
#   font-family: var(--visualization-font-family) !important;
#   font-weight: inherit;
#   font-style: inherit;
#   font-size: var(--visualization-token-font-size);
#   padding: 0;
#   margin-right: 0.2em;
#   white-space: pre-wrap;
#   border-radius: 0.5em;
#   background-color: transparent;
#   border: 0px solid transparent;
#   outline: 1px solid transparent;
#   color: var(--text-color);
#   z-index: 0;
# }
#
# /*
# * Styles of the highlighted words with attribution colors: the inputs and some of the outputs.
# */
# .highlighted-word-style {
#   position: relative;
#   /* mandatory for the tooltip to be positioned correctly */
# }
#
# /* Highlighted words tooltips style */
# .highlighted-word-style .tooltiptext {
#   visibility: hidden;
#   text-align: center;
#   padding: 0.2em 0.45em;
#   border-radius: 0.5em;
#   white-space: nowrap;
#   font-family: var(--visualization-font-family);
#   font-size: var(--visualization-tooltip-font-size);
#   line-height: 1.2;
#   color: #222;
#   background-color: #e6e6e6;
#   /* Position of the tooltip w/r to the parent element */
#   position: absolute;
#   z-index: 1;
#   left: 50%;
#   bottom: 125%;
#   transform: translateX(-50%);
# }
#
# .highlighted-word-style .tooltiptext::after {
#   content: "";
#   position: absolute;
#   z-index: 1;
#   top: 100%;
#   /* Triangle at the bottom of the tooltip */
#   left: 50%;
#   margin-left: -0.3em;
#   border-width: 0.3em;
#   border-style: solid;
#   border-color: #e6e6e6 transparent transparent transparent;
# }
#
# .highlighted-word-style:hover .tooltiptext {
#   visibility: visible;
# }
#
# /*
# * Style of the reactive/clickable elements.
# */
# .reactive-word-style:hover {
#   transform: scale(1.15);
#   box-shadow: 0 4px 8px rgba(0, 0, 0, 0.5);
# }
#
# /*
# * Style of the words (concepts & outputs) currently selected by the user.
# */
# .selected-style {
#   outline: 2px solid red !important;
# }
#
# .is-emphasized {
#   font-weight: 600;
# }
#
# .is-hidden {
#   display: none;
# }
#
# /*
# * Style of the concepts in the concept menu.
# */
# .concept-style {
#   margin-right: 0.75em;
#   padding-left: 0.25em;
#   padding-right: 0.25em;
#   outline: 2px solid transparent;
# }
#
# /*
# * Style of the class buttons/labels.
# */
# .class-style {
#   margin-right: 0.75em;
#   padding-left: 0.25em;
#   padding-right: 0.25em;
#   outline: 2px solid transparent;
#   cursor: pointer;
# }
#
# /*
# * Style for class buttons with colored backgrounds (default multi-class view)
# */
# .class-style-colored-border {
#   outline-width: 2px;
#   outline-style: solid;
# }
#
# </style><script>
# (function () {
#     /**
#      * StateManager - Manages visualization state and transitions
#      */
#     window.StateManager = class StateManager {
#         constructor() {
#             this.activatedClassId = null;
#             this.selectedClassId = null;
#             this.currentOutputId = null;
#             this.selectedOutputId = null;
#         }
#
#         /**
#          * Set the active class (on hover)
#          * @param {number|null} classId - The class ID to activate
#          * @returns {object} What changed: { classChanged: boolean }
#          */
#         setActiveClass(classId) {
#             const changed = this.activatedClassId !== classId;
#             this.activatedClassId = classId;
#             return { classChanged: changed };
#         }
#
#         /**
#          * Toggle the selected class (on click)
#          * @param {number} classId - The class ID to toggle
#          * @returns {object} What changed: { classChanged: boolean, wasDeselected: boolean }
#          */
#         toggleSelectedClass(classId) {
#             const wasSelected = this.selectedClassId === classId;
#             if (wasSelected) {
#                 this.selectedClassId = null;
#                 this.activatedClassId = null;
#             } else {
#                 this.selectedClassId = classId;
#                 this.activatedClassId = classId;
#             }
#             return { classChanged: true, wasDeselected: wasSelected };
#         }
#
#         /**
#          * Restore active class to selected class (on mouse out)
#          * @returns {object} What changed: { classChanged: boolean }
#          */
#         restoreSelectedClass() {
#             const changed = this.activatedClassId !== this.selectedClassId;
#             this.activatedClassId = this.selectedClassId;
#             return { classChanged: changed };
#         }
#
#         /**
#          * Set the active output (on hover)
#          * @param {number|null} outputId - The output ID to activate
#          * @param {boolean} resetClass - Whether to reset class selection
#          * @returns {object} What changed: { outputChanged: boolean, classChanged: boolean }
#          */
#         setActiveOutput(outputId, resetClass = false) {
#             // Do not override a selected output on hover.
#             if (this.selectedOutputId !== null && this.selectedOutputId !== outputId) {
#                 return { outputChanged: false, classChanged: false };
#             }
#             const outputChanged = this.currentOutputId !== outputId;
#             const classChanged = resetClass && (this.activatedClassId !== null || this.selectedClassId !== null);
#
#             this.currentOutputId = outputId;
#             if (resetClass) {
#                 this.activatedClassId = null;
#                 this.selectedClassId = null;
#             }
#
#             return { outputChanged, classChanged };
#         }
#
#         /**
#          * Toggle the selected output (on click)
#          * @param {number} outputId - The output ID to toggle
#          * @param {boolean} resetClass - Whether to reset class selection
#          * @returns {object} What changed: { outputChanged: boolean, classChanged: boolean, wasDeselected: boolean }
#          */
#         toggleSelectedOutput(outputId, resetClass = false) {
#             const wasSelected = this.selectedOutputId === outputId;
#             const outputChanged = true;
#
#             if (wasSelected) {
#                 this.selectedOutputId = null;
#                 this.currentOutputId = null;
